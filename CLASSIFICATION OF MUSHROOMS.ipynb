# %% [markdown]
# # Data Set Information:
# This data set includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family (pp. 500-525). Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended. This latter class was combined with the poisonous one. The Guide clearly states that there is no simple rule for determining the edibility of a mushroom; no rule like ``leaflets three, let it be'' for Poisonous Oak and IvyPROBLEM DEFINITION

# %% [markdown]
# # PROBLEM DEFINITION:
#
# # IN THIS PROJECT WE HAVE TO CLASSIFY THE MUSHROOM AS "EDIBLE" OR "POISONOUS" BY THE GIVEN DATA-SET INFORMATION.

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Before loading the Data-set we will modify the column title for all the  given elemnets in the columns.we change them with the help of the Attribute Information given in the Data-set information.
#
# Attribute Information:
#
# 1. cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# 2. cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
# 3. cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r, pink=p,purple=u,red=e,white=w,yellow=y
# 4. bruises?: bruises=t,no=f
# 5. odor: almond=a,anise=l,creosote=c,fishy=y,foul=f, musty=m,none=n,pungent=p,spicy=s
# 6. gill-attachment: attached=a,descending=d,free=f,notched=n
# 7. gill-spacing: close=c,crowded=w,distant=d
# 8. gill-size: broad=b,narrow=n
# 9. gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e, white=w,yellow=y
# 10. stalk-shape: enlarging=e,tapering=t
# 11. stalk-root: bulbous=b,club=c,cup=u,equal=e, rhizomorphs=z,rooted=r,missing=?
# 12. stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
# 13. stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
# 14. stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y
# 15. stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y
# 16. veil-type: partial=p,universal=u
# 17. veil-color: brown=n,orange=o,white=w,yellow=y
# 18. ring-number: none=n,one=o,two=t
# 19. ring-type: cobwebby=c,evanescent=e,flaring=f,large=l, none=n,pendant=p,sheathing=s,zone=z
# 20. spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r, orange=o,purple=u,white=w,yellow=y
# 21. population: abundant=a,clustered=c,numerous=n, scattered=s,several=v,solitary=y
# 22. habitat: grasses=g,leaves=l,meadows=m,paths=p, urban=u,waste=w,woods=d

# %%
#loading the dataset
df=pd.read_csv("mushroom.csv")
df.head()
# Out:
#   classes cap shape cap surface cap color bruises odor gill attachment  \
# 0       e         x           s         y       t    a               f
# 1       e         b           s         w       t    l               f
# 2       p         x           y         w       t    p               f
# 3       e         x           s         g       f    n               f
# 4       e         x           y         y       t    a               f
#
#   gill spacing gill size gill color  ... stalk-surface-bb stalk-color-ab  \
# 0            c         b          k  ...                s              w
# 1            c         b          n  ...                s              w
# 2            c         n          n  ...                s              w
# 3            w         b          k  ...                s              w
# 4            c         b          n  ...                s              w
#
#   stalk-color-br veil-type veil-color ring-number ring-type spore-print-color  \
# ...

# %%
df
# Out:
#      classes cap shape cap surface cap color bruises odor gill attachment  \
# 0          e         x           s         y       t    a               f
# 1          e         b           s         w       t    l               f
# 2          p         x           y         w       t    p               f
# 3          e         x           s         g       f    n               f
# 4          e         x           y         y       t    a               f
# ...      ...       ...         ...       ...     ...  ...             ...
# 8118       e         k           s         n       f    n               a
# 8119       e         x           s         n       f    n               a
# 8120       e         f           s         n       f    n               a
# 8121       p         k           y         n       f    y               f
# 8122       e         x           s         n       f    n               a
#
#      gill spacing gill size gill color  ... stalk-surface-bb stalk-color-ab  \
# ...

# %%
df.columns
# Out:
# Index(['classes', 'cap shape', 'cap surface', 'cap color', 'bruises', 'odor',
#        'gill attachment', 'gill spacing', 'gill size', 'gill color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-ab', 'stalk-surface-bb',
#        'stalk-color-ab', 'stalk-color-br', 'veil-type', 'veil-color',
#        'ring-number', 'ring-type', 'spore-print-color', 'population',
#        'habitat'],
#       dtype='object')

# %% [markdown]
# # As we see above, we have changed all the column titles for the better understanding of the given data-set.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8123 entries, 0 to 8122
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   classes            8123 non-null   object
#  1   cap shape          8123 non-null   object
#  2   cap surface        8123 non-null   object
#  3   cap color          8123 non-null   object
#  4   bruises            8123 non-null   object
#  5   odor               8123 non-null   object
#  6   gill attachment    8123 non-null   object
#  7   gill spacing       8123 non-null   object
#  8   gill size          8123 non-null   object
#  9   gill color         8123 non-null   object
#  10  stalk-shape        8123 non-null   object
#  11  stalk-root         8123 non-null   object
#  12  stalk-surface-ab   8123 non-null   object
#  13  stalk-surface-bb   8123 non-null   object
#  14  stalk-color-ab     8123 non-null   object
#  15  stalk-color-br     8123 non-null   object
# ...

# %%
df.describe()
# Out:
#        classes cap shape cap surface cap color bruises  odor gill attachment  \
# count     8123      8123        8123      8123    8123  8123            8123
# unique       2         6           4        10       2     9               2
# top          e         x           y         n       f     n               f
# freq      4208      3655        3244      2283    4748  3528            7913
#
#        gill spacing gill size gill color  ... stalk-surface-bb stalk-color-ab  \
# count          8123      8123       8123  ...             8123           8123
# unique            2         2         12  ...                4              9
# top               c         b          b  ...                s              w
# freq           6811      5612       1728  ...             4935           4463
#
#        stalk-color-br veil-type veil-color ring-number ring-type  \
# count            8123      8123       8123        8123      8123
# ...

# %%
df.shape
# Out:
# (8123, 23)

# %% [markdown]
# # Also from the given data-set we can infer that all the data types are categorical. Thus we convert them to integer type by using the label encoder method.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for columns in df.columns:
    df[columns]=le.fit_transform(df[columns])

# %%
df
# Out:
#       classes  cap shape  cap surface  cap color  bruises  odor  \
# 0           0          5            2          9        1     0
# 1           0          0            2          8        1     3
# 2           1          5            3          8        1     6
# 3           0          5            2          3        0     5
# 4           0          5            3          9        1     0
# ...       ...        ...          ...        ...      ...   ...
# 8118        0          3            2          4        0     5
# 8119        0          5            2          4        0     5
# 8120        0          2            2          4        0     5
# 8121        1          3            3          4        0     8
# 8122        0          5            2          4        0     5
#
#       gill attachment  gill spacing  gill size  gill color  ...  \
# 0                   1             0          0           4  ...
# 1                   1             0          0           5  ...
# ...

# %% [markdown]
# # IN THIS ABOVE TABLE WE CAN SEE ALL THE VALUES HAVE BEEN CHANGED USING THE LABEL ENCODER.
# # EX: "P" IS 1 WHICH MEANS POISONOUS AND "E" IS 0 WHICH MEANS EDIBLE

# %%
df.describe()
# Out:
#            classes    cap shape  cap surface    cap color      bruises  \
# count  8123.000000  8123.000000  8123.000000  8123.000000  8123.000000
# mean      0.481965     3.347901     1.827650     4.504740     0.415487
# std       0.499705     1.604323     1.229947     2.545972     0.492836
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill attachment  gill spacing    gill size   gill color  \
# count  8123.000000      8123.000000   8123.000000  8123.000000  8123.000000
# mean      4.144528         0.974147      0.161517     0.309122     4.810784
# std       2.103758         0.158705      0.368030     0.462160     3.540565
# ...

# %% [markdown]
# # From the above, we ca infer that the column "Veil Type" is not contributing any assistance in this data analysis.so we can drop that column.

# %%
df.drop(["veil-type"],axis=1,inplace=True)
df
# Out:
#       classes  cap shape  cap surface  cap color  bruises  odor  \
# 0           0          5            2          9        1     0
# 1           0          0            2          8        1     3
# 2           1          5            3          8        1     6
# 3           0          5            2          3        0     5
# 4           0          5            3          9        1     0
# ...       ...        ...          ...        ...      ...   ...
# 8118        0          3            2          4        0     5
# 8119        0          5            2          4        0     5
# 8120        0          2            2          4        0     5
# 8121        1          3            3          4        0     8
# 8122        0          5            2          4        0     5
#
#       gill attachment  gill spacing  gill size  gill color  ...  \
# 0                   1             0          0           4  ...
# 1                   1             0          0           5  ...
# ...

# %%
df.shape
# Out:
# (8123, 22)

# %% [markdown]
# # Finding NAN values

# %%
df.isnull().sum()
# Out:
# classes              0
# cap shape            0
# cap surface          0
# cap color            0
# bruises              0
# odor                 0
# gill attachment      0
# gill spacing         0
# gill size            0
# gill color           0
# stalk-shape          0
# stalk-root           0
# stalk-surface-ab     0
# stalk-surface-bb     0
# stalk-color-ab       0
# stalk-color-br       0
# veil-color           0
# ring-number          0
# ring-type            0
# spore-print-color    0
# population           0
# habitat              0
# dtype: int64

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
df["classes"].unique()
# Out:
# array([0, 1])

# %%
df["classes"].value_counts()
# Out:
# 0    4208
# 1    3915
# Name: classes, dtype: int64

# %%
sn.countplot(x="classes",data=df)

# %% [markdown]
# # From the above count plot we can see that both the Edible and Poisonous mushrooms are more or less of the same numbers in the given data-set.

# %%
#BI-VARIATE ANALYSIS
corr=df.corr()
plt.figure(figsize=(15,15))
sn.heatmap(corr,annot=True)

# %% [markdown]
# # On seeing the above heat map we concur that Gill-color is highly negative correlated with the classes.since our target is to find the edibility of the mushroom, it is clear that we analyse the given data with respect to the classes. sometimes the highly negative values may contribute more to the accuracy of the analysis.
# # Also on seeing the heat map we can infer that there may be a instance of many outliers present in the given data-set. To confrim that we may use visualization of datas.

# %% [markdown]
# # DATA PRE-PROCESSING

# %%
collist=df.columns.values
ncol=11
nrow=11
plt.figure(figsize=(25,25))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sn.boxplot(df[collist[i]])

# %% [markdown]
# # This above box-plot confrims the presence of outliers in the data-set.so, we use z-score method to remove the outliers.

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.96455727, 1.02984283, 0.14013674, ..., 0.25054462, 1.3131121 ,
#         0.29553654],
#        [0.96455727, 2.08692816, 0.14013674, ..., 0.25054462, 1.3131121 ,
#         0.86756584],
#        [1.03674508, 1.02984283, 0.95323012, ..., 0.67025464, 0.51442924,
#         2.03066822],
#        ...,
#        [0.96455727, 0.84021976, 0.14013674, ..., 1.50967469, 2.11179496,
#         0.28601465],
#        [1.03674508, 0.21686556, 0.95323012, ..., 1.42829549, 0.28425362,
#         0.28601465],
#        [0.96455727, 1.02984283, 0.14013674, ..., 0.16916541, 2.11179496,
#         0.28601465]])

# %%
z[5555][17]
# Out:
# 3.4330262755098735

# %%
threshold=3
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       classes  cap shape  cap surface  cap color  bruises  odor  \
# 0           0          5            2          9        1     0
# 1           0          0            2          8        1     3
# 2           1          5            3          8        1     6
# 3           0          5            2          3        0     5
# 4           0          5            3          9        1     0
# ...       ...        ...          ...        ...      ...   ...
# 8112        1          3            3          2        0     8
# 8115        1          3            3          4        0     7
# 8116        1          3            2          2        0     8
# 8117        1          3            3          4        0     2
# 8121        1          3            3          4        0     8
#
#       gill attachment  gill spacing  gill size  gill color  ...  \
# 0                   1             0          0           4  ...
# 1                   1             0          0           5  ...
# ...

# %% [markdown]
# # PREPARING DATA-SET FOR TRAINING AND TESTING

# %%
x=df.drop("classes",axis=1)
y=df["classes"]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=42)

# %%
x_train.shape
# Out:
# (5686, 21)

# %%
y_train.shape
# Out:
# (5686,)

# %%
x_test.shape
# Out:
# (2437, 21)

# %%
y_test.shape
# Out:
# (2437,)

# %% [markdown]
# # MACHINE LEARNING MODELS

# %% [markdown]
# # For the above data-set we will use
# 1.LOGISTIC REGRESSION
#
# 2.NAIVES BAYES CLASSIFICATION
#
# 3.RANDOM FOREST

# %%
#Logictic Regression
lg=LogisticRegression()
lg.fit(x_train,y_train)#for Training purpose
lg_pred=lg.predict(x_test)#for Testing purpose
print(lg_pred)
print("\nAccuracy score : ",accuracy_score(y_test,lg_pred))
print("\nConfussion matrix : ",confusion_matrix(y_test,lg_pred))
print("\nclassification report : ",classification_report(y_test,lg_pred))
# Out:
# [1 0 0 ... 0 1 0]
#
# Accuracy score :  0.9528108329913828
#
# Confussion matrix :  [[1226   48]
#  [  67 1096]]
#
# classification report :                precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96      1274
#            1       0.96      0.94      0.95      1163
#
#     accuracy                           0.95      2437
#    macro avg       0.95      0.95      0.95      2437
# weighted avg       0.95      0.95      0.95      2437

# %%
#RANDOM FOREST REGRESSOR
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(RandomForestRegressor(),x_train,y_train,cv=5).mean()
print( f"Accuracy={r2score*100},cross_value_score={cvscore*100},and difference={(r2score*100)-(cvscore*100)}")
# Out:
# Accuracy=99.99991776127078,cross_value_score=99.99635200191325,and difference=0.003565759357528009

# %%
#NAIVE BAYES
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
gnb = GaussianNB()
gnb.fit(x_train,y_train)
y_pred=gnb.predict(x_test)
acc={metrics.accuracy_score(y_test, y_pred)*100}
print("Accuracy:",acc)
# Out:
# Accuracy: {93.63972096840378}

# %% [markdown]
# # From the above Machine Learning Models we can conclude that Random Forest Regressor has the highest accuracy rate of "99.99% with a negligble difference.
# # Thus, we will use "Random Forest Regressor" for the prediction.

# %% [markdown]
# # HYPER TUNNING THE MACHINE LEARNING MODEL :

# %%
#creating parameter list to pass in gridsearch CV
parameters={"criterion":["mae"],"n_estimators":[200]}

# %%
from sklearn.model_selection import GridSearchCV
GCV=GridSearchCV(rf,parameters,cv=5,scoring="r2")
GCV.fit(x_train,y_train)
GCV.best_estimator_#finding best estimator
GCV_pred=GCV.best_estimator_.predict(x_test)
print("final accuracy = ",r2_score(y_test,GCV_pred)*100)
# Out:
# final accuracy =  99.99298503639832

# %% [markdown]
# # SAVING THE MODEL

# %%
import joblib 
joblib.dump(rf,"mushroom.pkl")
# Out:
# ['mushroom.pkl']

# %% [markdown]
# # PREDICTING THE CLASS OF GIVEN MUSHROOM WITH A SAMPLE DATA

# %%
td=np.array([1,1,1,1,1,6,1,1,0,1,4,2,1,2,2,1,1,1,1,1,1])
td.shape
# Out:
# (21,)

# %%
td=td.reshape(1,-1)
td
# Out:
# array([[1, 1, 1, 1, 1, 6, 1, 1, 0, 1, 4, 2, 1, 2, 2, 1, 1, 1, 1, 1, 1]])

# %%
rf.predict(td)
# Out:
# array([0.98])

# %% [markdown]
# # This above result 0.98 which is  1 when rounded off shows that the given Mushroom is poisonous in nature.

# %%
a=np.array(y_test)
predicted=np.array(y_pred)
new=pd.DataFrame({"original":a,"predicted":predicted})
new.tail()
# Out:
#       original  predicted
# 2432         1          1
# 2433         0          0
# 2434         0          0
# 2435         1          1
# 2436         0          0

# %% [markdown]
# # CONCLUSION REMARKS:
# # We can visibly see that the Machine learning model performs well with a higher accuracy of prediction.
